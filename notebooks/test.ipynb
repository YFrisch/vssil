# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms as tf
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image

# %%
image = Image.open("/home/yannik/Bilder/master_thesis/spatial_soft_argmax.png").convert('RGB')
transforms = tf.ToTensor()
img_tensor = transforms(image)

# %%
img_tensor.shape
# Out:
# torch.Size([3, 250, 1124])

# %%
fig = plt.figure(figsize=(15, 5))
plt.imshow(img_tensor.permute(1, 2, 0))
plt.axis('off')
plt.plot()
plt.show()
fig.savefig('/home/yannik/spatial_soft_argmax.svg', bbox_inches='tight')
